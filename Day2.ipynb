# %% [markdown]
# # Day 2 Start Here Vedio 19

# %%
# Python Premetive Datatypes
# String
print("Hello"[0])
print("Hello"[4])
print("123"+"456")
# Integer
print(123+456)
# Out:
# H
# o
# 123456
# 579

# %%
# Video 20
num_char=len(input("what is your name ?"))
#new_num_char=str(num_char)
#print("your name has " + new_num_char + "character")
