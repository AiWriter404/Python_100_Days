# %% [markdown]
# # Day 1 End Project

# %%
# Create a Greeting for your programm
print("Welcome to the Band Name Generator")
# Out:
# Welcome to the Band Name Generator

# %%
# Ask the user about city he grew in
city=input("which city you grew up ?\n")
print(city)

# %%
# Ask the user for the name of his pet
pet=input("what is the name of your pet ?\n")

# %%
# Combine the name of city and pet
# and show them for the band name
print("Your Band Name Could be " + city + " " + pet)
# Make sure the input cursor shows on the new line

# %% [markdown]
# # Start Other Days code
